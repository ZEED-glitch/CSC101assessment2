# %%
# Define the path to your text file.
file_path = '/content/My_data_Story.txt'

# Use a 'with' statement to open the file in read mode ('r').
# This ensures the file is automatically closed after its use.
with open(file_path, 'r') as file:

    # Read the entire content of the file into a variable.
    file_content = file.read()

    # Print the content to the console.
    print(file_content)
word_count = len(file_content.split())
print(f"The number of words in the program (text file content) is: {word_count}")
# Out:
# Weekend Schedule.
#
# Clock in my morning shift from 9am-6pm,
#
# Drive to my friends home for 1hr later on
#
# Play video games for 2 hrs
#
# Watch football game
#
# Yea that's for the weekend
# The number of words in the program (text file content) is: 32

# %% [markdown]
# My data stroy is all about the coming Weeekend schedule.
#
# Inb the schedule it contains the plans for the coming weekend in relation to my time availability.
#
# This is the prompt i used to get a program that displays content in my text file; upload a text file on AI and ask AI to write a code that displays context in it.Got a clear program that displayed the code and it run well.
#
# AI is a great learning partner when you really know what needs to be prompyted to get the best results, of course we know more than but we neeed to collaborate to get the best results.
