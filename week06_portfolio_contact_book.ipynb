# %%
contacts = {}

contacts = {
    "Alice": "0400 123 456",
    "Bob": "0412 987 654",
    "Charlie": "0455 555 123"}
contacts["Tony"] ="0451 923 560"
contacts["Bob"] = "0411 000 999"
print("My contact Book:")
for name, number in contacts.items():
    print(name, number)

contacts ={"Alice": {"phone": "0400 123 456", "email": "alice@example.com"},
    "Bob":   {"phone": "0411 222 333", "email": "bob@example.com"},
    "Charlie": {"phone": "0422 555 777", "email": "charlie@work.co"},
    "Tony": {"phone": "0451 923 560", "email": "2500086@adci.edu.au"}
}

print("\nUpdated contact Book:")
for name, emails in contacts.items():
    print(name, emails)
# Out:
# My contact Book:
# Alice 0400 123 456
# Bob 0411 000 999
# Charlie 0455 555 123
# Tony 0451 923 560
#
# Updated contact Book:
# Alice {'phone': '0400 123 456', 'email': 'alice@example.com'}
# Bob {'phone': '0411 222 333', 'email': 'bob@example.com'}
# Charlie {'phone': '0422 555 777', 'email': 'charlie@work.co'}
# Tony {'phone': '0451 923 560', 'email': '2500086@adci.edu.au'}
